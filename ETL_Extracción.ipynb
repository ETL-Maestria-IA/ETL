# %%
#Cargamos librerías y nos conectamos a la API de Kaggle
import pandas as pd
import os
os.environ['KAGGLE_USERNAME'] = "julianherrera93"
os.environ['KAGGLE_KEY'] = "208b2c73cfbb9b351593d273849c2cc3"
# !kaggle datasets list

# %%
#Solicitamos descarga del dataset encontrado
import kaggle
kaggle.api.authenticate()
kaggle.api.dataset_download_files("jocelyndumlao/soil-data-grevena", path=".", unzip=True)
kaggle.api.dataset_download_files("snmahsa/soil-nutrients", path= ".", unzip= True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/jocelyndumlao/soil-data-grevena
# Dataset URL: https://www.kaggle.com/datasets/snmahsa/soil-nutrients

# %%
#Posterior a la descarga, cargamos en entorno de trabajo
df_Soil_data = pd.read_excel("/content/r7tjn68rmw-1/SOIL DATA GR.xlsx")
df_soil_data_grevena = pd.read_csv("/content/Soil Nutrients.csv")

# %%
df_Soil_data.head()
# Out:
#    ID  Sand %  Clay %  Silt %     pH  EC mS/cm    O.M. %  CACO3 %  N_NO3 ppm  \
# 0   1    42.0    38.0    20.0  5.162     0.274  3.783414     0.00  14.462366
# 1   2    54.0    26.0    20.0  6.071     0.355  1.451688     0.00  14.587814
# 2   3    28.0    36.0    36.0  6.921     0.675  1.767599     0.40  14.910394
# 3   4    58.0    20.0    22.0  7.704     0.355  0.718322     6.80   4.211470
# 4   5    33.2    41.2    25.6  7.609     0.392  0.996625     4.39   6.111111
#
#        P ppm  K ppm   Mg ppm  Fe ppm  Zn ppm  Mn ppm  Cu ppm  B ppm
# 0  18.608840     147    1115   91.32   0.894   27.06   1.768   0.40
# 1  32.742137     180    1055   60.04   3.660   17.58   1.684   0.41
# 2  19.024525     183    1215   61.24   3.060   18.00   1.840   0.46
# 3   6.276846     116     327   19.54   1.640    5.04   0.844   0.50
# 4   6.553970     228     939   25.84   0.180    7.16   1.216   0.40

# %%
df_soil_data_grevena.head()
# Out:
#          Name Fertility       Photoperiod  Temperature    Rainfall        pH  \
# 0  Strawberry  Moderate       Day Neutral    20.887923  747.860765  6.571548
# 1  Strawberry  Moderate       Day Neutral    18.062721  711.104329  6.251806
# 2  Strawberry  Moderate  Short Day Period    16.776782  774.038247  6.346916
# 3  Strawberry  Moderate  Short Day Period    14.281000  665.633506  6.259598
# 4  Strawberry  Moderate       Day Neutral    21.444490  806.531455  6.384368
#
#    Light_Hours  Light_Intensity         Rh    Nitrogen  Phosphorus  \
# 0    13.091483       533.762876  91.197196  170.800381  118.670058
# 1    13.063016       505.789101  91.939623  179.290364  121.020244
# 2    12.945927       512.985617  91.387286  181.440732  116.936806
# 3    13.318922       484.860067  91.254598  176.165282  122.233153
# 4    13.312915       512.747307  92.354829  182.935334  126.088234
#
#     Potassium      Yield Category_pH Soil_Type  Season  N_Ratio  P_Ratio  \
# ...

# %%
#Realizamos identificación estadistica a las variables numéricas
df_Soil_data.describe()
# Out:
#                ID      Sand %      Clay %      Silt %          pH    EC mS/cm  \
# count  781.000000  781.000000  781.000000  781.000000  781.000000  781.000000
# mean   391.000000   31.529321   34.997183   33.473496    7.133668    0.452793
# std    225.599572   10.978371   11.252452    8.384172    0.897823    0.304841
# min      1.000000   10.000000    6.000000   14.000000    4.490000    0.134000
# 25%    196.000000   24.000000   28.000000   28.000000    6.660000    0.338000
# 50%    391.000000   30.000000   36.000000   32.000000    7.550000    0.404000
# 75%    586.000000   38.000000   44.000000   38.000000    7.780000    0.497000
# max    781.000000   70.000000   64.000000   68.000000    8.200000    5.621000
#
#            O.M. %     CACO3 %   N_NO3 ppm       P ppm       K ppm   \
# count  781.000000  781.000000  781.000000  781.000000   781.000000
# mean     2.028909   13.422049   11.623384   13.840659   296.226633
# ...

# %%
df_soil_data_grevena.head(5)
# Out:
#          Name Fertility       Photoperiod  Temperature    Rainfall        pH  \
# 0  Strawberry  Moderate       Day Neutral    20.887923  747.860765  6.571548
# 1  Strawberry  Moderate       Day Neutral    18.062721  711.104329  6.251806
# 2  Strawberry  Moderate  Short Day Period    16.776782  774.038247  6.346916
# 3  Strawberry  Moderate  Short Day Period    14.281000  665.633506  6.259598
# 4  Strawberry  Moderate       Day Neutral    21.444490  806.531455  6.384368
#
#    Light_Hours  Light_Intensity         Rh    Nitrogen  Phosphorus  \
# 0    13.091483       533.762876  91.197196  170.800381  118.670058
# 1    13.063016       505.789101  91.939623  179.290364  121.020244
# 2    12.945927       512.985617  91.387286  181.440732  116.936806
# 3    13.318922       484.860067  91.254598  176.165282  122.233153
# 4    13.312915       512.747307  92.354829  182.935334  126.088234
#
#     Potassium      Yield Category_pH Soil_Type  Season  N_Ratio  P_Ratio  \
# ...

# %%
#Realizamos identificación de tipos y dimensiones
  print(df_Soil_data.dtypes)
  print(df_Soil_data.shape)
# Out:
# ID             int64
# Sand %       float64
# Clay %       float64
# Silt %       float64
# pH           float64
# EC mS/cm     float64
# O.M. %       float64
# CACO3 %      float64
# N_NO3 ppm    float64
# P ppm        float64
# K ppm          int64
# Mg ppm         int64
# Fe ppm       float64
# Zn ppm       float64
# Mn ppm       float64
# Cu ppm       float64
# B ppm        float64
# dtype: object
# (781, 17)

# %%
print(df_soil_data_grevena.dtypes)
print(df_soil_data_grevena.shape)
# Out:
# ID             int64
# Sand %       float64
# Clay %       float64
# Silt %       float64
# pH           float64
# EC mS/cm     float64
# O.M. %       float64
# CACO3 %      float64
# N_NO3 ppm    float64
# P ppm        float64
# K ppm          int64
# Mg ppm         int64
# Fe ppm       float64
# Zn ppm       float64
# Mn ppm       float64
# Cu ppm       float64
# B ppm        float64
# dtype: object
# (781, 17)

# %%
# !pip install datasets

# %%
from datasets import load_dataset

# Cargar el dataset desde hugging face
df_soil_data_hugging = load_dataset("Prazzwal07/soil_data")

# %%
# Convertirmos la partición 'train' a un DataFrame de Pandas para poder analizar los datos
df_soil_data_hugging = df_soil_data_hugging["train"].to_pandas()

# %%
df_soil_data_hugging.head(5)
# Out:
#    Location  Longitude  Latitude       parentsoil    ph     clay  \
# 0    Babala      81.23     29.32  slate, phyllite  6.48  10.28 %
# 1  Devistan      81.20     29.30  slate, phyllite  6.48  13.25 %
# 2   Devikot      81.17     29.27        Quartzite  6.27  14.01 %
# 3  Patalkot      81.13     29.25        Quartzite  6.16  14.12 %
# 4      Duni      81.10     29.25  slate, phyllite  5.93  18.62 %
#
#   organicMatter totalNitrogen     boron          p2o5     sand
# 0        3.13 %        0.14 %  0.72 ppm   54.91 kg/ha  52.04 %
# 1        3.47 %        0.13 %  0.78 ppm   90.48 kg/ha   52.6 %
# 2        3.35 %        0.13 %   0.9 ppm   70.26 kg/ha  51.25 %
# 3        3.12 %        0.17 %  0.87 ppm   68.85 kg/ha  57.22 %
# 4        3.49 %         0.2 %  0.93 ppm  103.14 kg/ha  50.65 %

# %%
print(df_soil_data_hugging.dtypes)
print(df_soil_data_hugging.shape)
# Out:
# Location          object
# Longitude        float64
# Latitude         float64
# parentsoil        object
# ph               float64
# clay              object
# organicMatter     object
# totalNitrogen     object
# boron             object
# p2o5              object
# sand              object
# dtype: object
# (1359, 11)

# %%
# !pip install arcgis
# Out:
# ...
#   Using cached arcgis-2.4.0.tar.gz (46.8 MB)

# %%
from arcgis.gis import GIS
import pandas as pd

gis = GIS()
url = "https://services9.arcgis.com/Np9UOdtKcSTyWrE5/arcgis/rest/services/Propiedades_de_Suelos_Cuenca_de_Huanquisco/FeatureServer/0"

# Cargar los datos desde ArcGIS
feature_layer = gis.content.get(url)

# Obtener los datos como un DataFrame para el análisis
df_soil_data_huanquisco = pd.DataFrame.spatial.from_layer(feature_layer)

# %%
df_soil_data_huanquisco.head(5)

# %%
print(df_soil_data_huanquisco.dtypes)
print(df_soil_data_huanquisco.shape)
