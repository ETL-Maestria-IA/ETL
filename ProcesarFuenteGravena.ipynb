# %%
#Cargamos librerías y nos conectamos a la API de Kaggle
import pandas as pd
import os
os.environ['KAGGLE_USERNAME'] = "julianherrera93"
os.environ['KAGGLE_KEY'] = "208b2c73cfbb9b351593d273849c2cc3"

# %%
#Solicitamos descarga del dataset encontrado
import kaggle
kaggle.api.authenticate()
kaggle.api.dataset_download_files("snmahsa/soil-nutrients", path= ".", unzip= True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/snmahsa/soil-nutrients

# %%
#Posterior a la descarga, cargamos en entorno de trabajo
df_soil_data_grevena = pd.read_csv("/content/Soil Nutrients.csv")

# %%
df_soil_data_grevena.head()
# Out:
#          Name Fertility       Photoperiod  Temperature    Rainfall        pH  \
# 0  Strawberry  Moderate       Day Neutral    20.887923  747.860765  6.571548
# 1  Strawberry  Moderate       Day Neutral    18.062721  711.104329  6.251806
# 2  Strawberry  Moderate  Short Day Period    16.776782  774.038247  6.346916
# 3  Strawberry  Moderate  Short Day Period    14.281000  665.633506  6.259598
# 4  Strawberry  Moderate       Day Neutral    21.444490  806.531455  6.384368
#
#    Light_Hours  Light_Intensity         Rh    Nitrogen  Phosphorus  \
# 0    13.091483       533.762876  91.197196  170.800381  118.670058
# 1    13.063016       505.789101  91.939623  179.290364  121.020244
# 2    12.945927       512.985617  91.387286  181.440732  116.936806
# 3    13.318922       484.860067  91.254598  176.165282  122.233153
# 4    13.312915       512.747307  92.354829  182.935334  126.088234
#
#     Potassium      Yield Category_pH Soil_Type  Season  N_Ratio  P_Ratio  \
# ...

# %%
df_soil_data_grevena.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15400 entries, 0 to 15399
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             15400 non-null  object
#  1   Fertility        15400 non-null  object
#  2   Photoperiod      15400 non-null  object
#  3   Temperature      15400 non-null  float64
#  4   Rainfall         15400 non-null  float64
#  5   pH               15400 non-null  float64
#  6   Light_Hours      15400 non-null  float64
#  7   Light_Intensity  15400 non-null  float64
#  8   Rh               15400 non-null  float64
#  9   Nitrogen         15400 non-null  float64
#  10  Phosphorus       15400 non-null  float64
#  11  Potassium        15400 non-null  float64
#  12  Yield            15400 non-null  float64
#  13  Category_pH      15400 non-null  object
#  14  Soil_Type        15400 non-null  object
#  15  Season           15400 non-null  object
# ...

# %%
# Verificar valores nulos
print("\nValores nulos por columna:")
print(df_soil_data_grevena.isnull().sum())

# %%
# 3. Identificar valores duplicados
print("\nNúmero de filas duplicadas:", df_soil_data_grevena.duplicated().sum())
# Out:
# Número de filas duplicadas: 0

# %%
# Identificar valores fuera de rango
print("\nResumen estadístico:")
print(df_soil_data_grevena.describe())
# Out:
# Resumen estadístico:
#         Temperature      Rainfall            pH   Light_Hours  \
# count  15400.000000  15400.000000  15400.000000  15400.000000
# mean      20.801671    948.814222      6.473372      9.459365
# std        4.415164    340.884493      0.449111      2.588466
# min        9.355908    409.927161      4.888871      5.044913
# 25%       17.915142    707.799164      6.245973      7.017129
# 50%       19.929578    846.623453      6.466286      8.985917
# 75%       22.936714   1109.157262      6.697254     12.019180
# max       39.913892   2508.052849      8.023210     15.918024
#
#        Light_Intensity            Rh      Nitrogen    Phosphorus  \
# count     15400.000000  15400.000000  15400.000000  15400.000000
# mean        398.048832     67.117251    142.769483    107.659893
# std         190.512173     19.005233     58.524592     72.778284
# min          69.146572     29.877266     41.725552     13.155191
# ...

# %%
# Agrupar por Name y Fertility y contar la cantidad de registros en cada grupo
df_grouped = df_soil_data_grevena.groupby(["Name", "Fertility"]).size().reset_index(name="Cantidad")

# Mostrar los primeros resultados
print(df_grouped.head())
# Out:
#         Name Fertility  Cantidad
# 0    Arugula  Moderate       700
# 1  Asparagus      High       700
# 2       Beet      High       700
# 3   Broccoli      High       700
# 4    Cabbage      High       700

# %%
import requests
import json
import pandas as pd
import time  # Importar la librería para medir el tiempo

# Iniciar el temporizador
start_time = time.time()

# Convertir el dataframe a formato JSON (solo los registros)
data_json = df_soil_data_grevena.to_dict(orient='records')

# URL de la API con la clave de API (cambia la IP y la clave según corresponda)
url = "http://3.123.234.166/api.php?api_key=Colombia25*"

# Enviar los datos a la API mediante POST
response = requests.post(url, json=data_json, headers={'Content-Type': 'application/json'})

# Finalizar el temporizador
end_time = time.time()

# Calcular el tiempo en minutos
elapsed_time = (end_time - start_time) / 60

# Verificar el estado de la respuesta y el contenido
print("Status Code:", response.status_code)
print("Response Text:", response.text)

# Ver la respuesta de la API
try:
    print(response.json())
except json.JSONDecodeError:
    print("Error al decodificar la respuesta JSON.")

# Mostrar el tiempo de carga en minutos
print(f"Tiempo de carga: {elapsed_time:.2f} minutos")
# Out:
# Status Code: 200
# Response Text: {"message":"Datos insertados correctamente"}
# {'message': 'Datos insertados correctamente'}
# Tiempo de carga: 1.65 minutos
